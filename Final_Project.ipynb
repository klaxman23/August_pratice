# %% [markdown]
# <a href="https://colab.research.google.com/github/klaxman23/August_pratice/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Final project

# %% [markdown]
# This notebook presents the final project for this course. It demonstrates the use of Python and data science tools to analyze data, perform computations, and present results in a clear and structured manner.

# %% [markdown]
# ## Data Science Languages
#
# Some of the commonly used languages in data science include:
#
# - Python
# - R
# - SQL
# - Julia
# - Scala
# - MATLAB

# %% [markdown]
# ## Data Science Libraries
#
# Some of the popular libraries used in data science include:
#
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
# - PyTorch

# %% [markdown]
# ## Data Science Tools
#
# | Tool            | Description                           |
# |-----------------|---------------------------------------|
# | Jupyter Notebook| Interactive data analysis environment |
# | RStudio         | IDE for R programming                 |
# | Apache Spark    | Big data processing framework         |
# | TensorFlow      | Machine learning library              |
# | Tableau         | Data visualization tool               |

# %% [markdown]
# ## Arithmetic Expression Examples
#
# Below are some examples of basic arithmetic expressions in Python, including addition, subtraction, multiplication, and division.

# %%
# Multiply two numbers
a = 5
b = 4
multiplication = a * b

# Add two numbers
addition = a + b

multiplication, addition

# %% [markdown]
# Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60

hours

# %% [markdown]
# Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)

# %% [markdown]
# ## Objectives
#
# In this notebook, you will learn how to:
#
# - List popular languages used in Data Science
# - Identify commonly used Data Science libraries
# - Create tables using Markdown
# - Perform basic arithmetic operations in Python
# - Convert units such as minutes to hours

# %% [markdown]
# Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)

# %% [markdown]
# ## Author
#
# Laxman K
